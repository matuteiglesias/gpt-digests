# %%
import pandas as pd
import json
from pathlib import Path

# Base directory
base = Path("./../outputs/eda_units/may-aug_daily_combo2_soft/")

# CSVs
csv_files = [
    "co_tag_pairs.csv",
    "doc_tag_long.csv",
    "edges_backbone.csv",
    "edges_bridges.csv",
    "edges_default.csv",
    "edges_niche.csv",
    "edges_audit.csv",
    # "edges_backbone_topk.csv",
    # "edges_bridges_topk.csv",
    # "edges_default_topk.csv",
    # "edges_niche_topk.csv",
    "tag_communities.csv",
]

# JSONs
json_files = [
    "gates.json",
    "quantiles.json",
    "counts.json",
    "index.json",
]

# --- Load all CSVs into dict of DataFrames ---
dfs = {}
for fname in csv_files:
    fpath = base / fname
    if fpath.exists():
        try:
            dfs[fname] = pd.read_csv(fpath)
        except Exception as e:
            print(f"⚠️  Could not read {fname}: {e}")

# --- Load JSONs ---
jdata = {}
for fname in json_files:
    fpath = base / fname
    print(fpath)
    if fpath.exists():
        try:
            with open(fpath, "r", encoding="utf-8") as f:
                jdata[fname] = json.load(f)
        except Exception as e:
            print(f"⚠️  Could not read {fname}: {e}")

# --- Basic exploration per DataFrame ---
for name, df in dfs.items():
    print(f"\n=== {name} ===")
    print("Shape:", df.shape)
    print("Columns:", list(df.columns))
    print(df.head(8))
    print("\nColumn types:")
    print(df.dtypes)
    print("\nNon-null counts:")
    print(df.count())
    print("\nUnique counts:")
    print(df.nunique())
    # top values per column
    for col in df.columns:
        vc = df[col].value_counts(dropna=False).head(15)
        print(f"\nTop 5 values for {col}:")
        print(vc)

# --- Exploration for JSONs ---
for name, obj in jdata.items():
    print(f"\n=== {name} ===")
    if isinstance(obj, dict):
        for k, v in obj.items():
            print(f"{k}: {v}")
    else:
        print(type(obj), obj)
# Out:
# ../outputs/eda_units/may-aug_daily_combo2_soft/gates.json
# ../outputs/eda_units/may-aug_daily_combo2_soft/quantiles.json
# ../outputs/eda_units/may-aug_daily_combo2_soft/counts.json
# ../outputs/eda_units/may-aug_daily_combo2_soft/index.json
#
# === co_tag_pairs.csv ===
# Shape: (619, 9)
# Columns: ['tag_a', 'tag_b', 'co_docs', 'lift', 'npmi', 'lex_a', 'lex_b', 'is_tautology_like', 'edge_score']
#                              tag_a                    tag_b  co_docs  \
# 0                     free:recetas         note_type:receta        2
# 1                 category:cooking          domain:culinary        2
# 2                      free:cocina         note_type:receta        2
# 3       domain:audio_transcription  note_type:transcription        2
# 4                      free:cocina             free:recetas        2
# 5                  category:health        domain:healthcare        9
# 6                  category:health       free:mental_health        2
# 7  format_type:audio_transcription  note_type:transcription        2
#
#          lift      npmi                lex_a          lex_b  \
# 0  146.153846  0.582238              recetas         receta
# 1  139.333333  0.576655              cooking       culinary
# 2  126.666667  0.565523               cocina         receta
# 3  118.750000  0.557984  audio_transcription  transcription
# 4  107.179487  0.546010               cocina        recetas
# 5   18.441176  0.412999               health     healthcare
# 6  102.450980  0.540739               health  mental_health
# 7   76.838235  0.507136  audio_transcription  transcription
#
#    is_tautology_like  edge_score
# 0              False    3.188455
# 1              False    3.127609
# 2              False    3.008013
# 3              False    2.928353
# 4              False    2.804016
# 5              False    2.771668
# 6              False    2.750146
# 7              False    2.418964
#
# Column types:
# tag_a                 object
# tag_b                 object
# co_docs                int64
# lift                 float64
# npmi                 float64
# lex_a                 object
# lex_b                 object
# is_tautology_like       bool
# edge_score           float64
# dtype: object
#
# Non-null counts:
# tag_a                619
# tag_b                619
# co_docs              619
# lift                 619
# npmi                 619
# lex_a                619
# lex_b                619
# is_tautology_like    619
# edge_score           619
# dtype: int64
#
# Unique counts:
# tag_a                165
# tag_b                173
# co_docs               32
# lift                 523
# npmi                 550
# lex_a                142
# lex_b                153
# is_tautology_like      1
# edge_score           550
# dtype: int64
#
# Top 5 values for tag_a:
# tag_a
# category:software_dev         39
# category:business             35
# category:data                 28
# domain:python                 25
# format_type:code              18
# category:programming          18
# category:docs_and_planning    18
# category:automation           16
# format_type:template          14
# format_type:guide             13
# free:career_development       13
# format_type:report            13
# free:automation               10
# free:ai                       10
# category:ai_agents            10
# Name: count, dtype: int64
#
# Top 5 values for tag_b:
# tag_b
# stage:reflect                34
# stage:execute                30
# msg_type:reflection          23
# msg_type:instruction         23
# stage:plan                   22
# note_type:insight            19
# free:web_development         15
# free:software_development    14
# free:python                  13
# free:pandas                  10
# free:job_applications         9
# msg_type:question             9
# note_type:analisis            7
# free:scripting                7
# note_type:evaluacion          7
# Name: count, dtype: int64
#
# Top 5 values for co_docs:
# co_docs
# 2     289
# 3     135
# 4      49
# 5      32
# 6      28
# 7      14
# 10     12
# 8       9
# 12      7
# 9       7
# 13      6
# 18      4
# 16      3
# 14      2
# 29      2
# Name: count, dtype: int64
#
# Top 5 values for lift:
# lift
# 1.232311     10
# 1.979167      7
# 1.187500      7
# 1.319444      5
# 17.075163     4
# 1.369235      4
# 4.799082      4
# 2.018739      3
# 2.053852      3
# 2.300242      3
# 1.371391      3
# 1.540389      3
# 2.464623      3
# 11.908832     3
# 3.042213      3
# Name: count, dtype: int64
#
# Top 5 values for npmi:
# npmi
# 0.079741    5
# 0.183201    4
# 0.331451    4
# 0.032380    4
# 0.025613    4
# 0.036706    4
# 0.084067    3
# 0.136417    3
# 0.066062    3
# 0.105363    3
# 0.036890    3
# 0.082053    3
# 0.021071    3
# 0.054984    3
# 0.026549    3
# Name: count, dtype: int64
#
# Top 5 values for lex_a:
# lex_a
# software_dev          40
# business              35
# data                  33
# automation            28
# python                25
# programming           21
# ai                    19
# code                  18
# docs_and_planning     18
# template              14
# report                13
# career_development    13
# guide                 13
# ai_agents             10
# data_analysis          8
# Name: count, dtype: int64
#
# Top 5 values for lex_b:
# lex_b
# reflect                 34
# execute                 30
# instruction             23
# reflection              23
# plan                    22
# insight                 19
# web_development         16
# job_applications        15
# python                  14
# software_development    14
# evaluacion              12
# pandas                  10
# question                 9
# analisis                 8
# data_science             8
# Name: count, dtype: int64
#
# Top 5 values for is_tautology_like:
# is_tautology_like
# False    619
# Name: count, dtype: int64
#
# Top 5 values for edge_score:
# edge_score
# 0.059805    5
# 0.315672    4
# 1.033283    4
# 0.009861    4
# 0.007417    4
# 0.012673    4
# 0.066471    3
# 0.210406    3
# 0.041047    3
# 0.104414    3
# 0.012800    3
# 0.063324    3
# 0.005020    3
# 0.028435    3
# 0.008926    3
# Name: count, dtype: int64
#
# === doc_tag_long.csv ===
# Shape: (20900, 2)
# Columns: ['doc_id', 'tag']
#                doc_id                     tag
# 0  u_cb1309c1bf95017b       note_type:insight
# 1  u_cb1309c1bf95017b           stage:execute
# 2  u_190edd3980ec3dfa    msg_type:instruction
# 3  u_190edd3980ec3dfa           stage:execute
# 4  u_765bf067376bbae2  category:data_analysis
# 5  u_765bf067376bbae2           stage:execute
# 6  u_747ad3d50e97be44        format_type:code
# 7  u_747ad3d50e97be44           stage:execute
#
# Column types:
# doc_id    object
# tag       object
# dtype: object
#
# Non-null counts:
# doc_id    20900
# tag       20900
# dtype: int64
#
# Unique counts:
# doc_id    10450
# tag         567
# dtype: int64
#
# Top 5 values for doc_id:
# doc_id
# u_cb1309c1bf95017b    2
# u_2105c28bb788e07e    2
# u_df741700a520dfcc    2
# u_b0fdc9363c652104    2
# u_bd98890969095c53    2
# u_0b2cc3e3aee71185    2
# u_3fc9408d329ac3c2    2
# u_670948e6449046e5    2
# u_04abf015cf4fc4d0    2
# u_107fa30e937ebea4    2
# u_debc6fadaf37d6f3    2
# u_c9ff26b6aaf54f93    2
# u_6cdf3d53c35efbda    2
# u_16e229c131d7e209    2
# u_f03503430d06fa6d    2
# Name: count, dtype: int64
#
# Top 5 values for tag:
# tag
# msg_type:instruction     1760
# stage:execute            1696
# format_type:guide        1016
# category:software_dev     687
# stage:reflect             649
# free:automation           631
# note_type:insight         598
# msg_type:reflection       582
# domain:python             504
# category:business         493
# stage:plan                482
# format_type:template      469
# category:programming      362
# format_type:code          352
# free:python               338
# Name: count, dtype: int64
#
# === edges_backbone.csv ===
# Shape: (1, 11)
# Columns: ['tag_a', 'tag_b', 'co_docs', 'lift', 'npmi', 'lex_a', 'lex_b', 'is_tautology_like', 'edge_score', 'ca', 'cb']
#            tag_a       tag_b  co_docs      lift     npmi lex_a lex_b  \
# 0  msg_type:idea  stage:plan       36  4.360324  0.25967  idea  plan
#
#    is_tautology_like  edge_score   ca   cb
# 0              False    1.380728  5.0  5.0
#
# Column types:
# tag_a                 object
# tag_b                 object
# co_docs                int64
# lift                 float64
# npmi                 float64
# lex_a                 object
# lex_b                 object
# is_tautology_like       bool
# edge_score           float64
# ca                   float64
# cb                   float64
# dtype: object
#
# Non-null counts:
# tag_a                1
# tag_b                1
# co_docs              1
# lift                 1
# npmi                 1
# lex_a                1
# lex_b                1
# is_tautology_like    1
# edge_score           1
# ca                   1
# cb                   1
# dtype: int64
#
# Unique counts:
# tag_a                1
# tag_b                1
# co_docs              1
# lift                 1
# npmi                 1
# lex_a                1
# lex_b                1
# is_tautology_like    1
# edge_score           1
# ca                   1
# cb                   1
# dtype: int64
#
# Top 5 values for tag_a:
# tag_a
# msg_type:idea    1
# Name: count, dtype: int64
#
# Top 5 values for tag_b:
# tag_b
# stage:plan    1
# Name: count, dtype: int64
#
# Top 5 values for co_docs:
# co_docs
# 36    1
# Name: count, dtype: int64
#
# Top 5 values for lift:
# lift
# 4.360324    1
# Name: count, dtype: int64
#
# Top 5 values for npmi:
# npmi
# 0.25967    1
# Name: count, dtype: int64
#
# Top 5 values for lex_a:
# lex_a
# idea    1
# Name: count, dtype: int64
#
# Top 5 values for lex_b:
# lex_b
# plan    1
# Name: count, dtype: int64
#
# Top 5 values for is_tautology_like:
# is_tautology_like
# False    1
# Name: count, dtype: int64
#
# Top 5 values for edge_score:
# edge_score
# 1.380728    1
# Name: count, dtype: int64
#
# Top 5 values for ca:
# ca
# 5.0    1
# Name: count, dtype: int64
#
# Top 5 values for cb:
# cb
# 5.0    1
# Name: count, dtype: int64
#
# === edges_bridges.csv ===
# Shape: (14, 11)
# Columns: ['tag_a', 'tag_b', 'co_docs', 'lift', 'npmi', 'lex_a', 'lex_b', 'is_tautology_like', 'edge_score', 'ca', 'cb']
#                         tag_a                   tag_b  co_docs       lift  \
# 0             free:deployment       free:hugging_face        2  16.417910
# 1             free:evaluacion      note_type:analisis        2  13.483871
# 2  category:docs_and_planning      free:documentacion        3   8.088235
# 3          format_type:report      note_type:analysis       10   4.254886
# 4               category:data  domain:data_processing        7   4.549129
# 5               msg_type:goal              stage:plan        4   4.817888
# 6                 category:ai                free:llm        2   6.675184
# 7   free:personal_development     msg_type:reflection        3   4.488832
#
#        npmi                 lex_a            lex_b  is_tautology_like  \
# 0  0.326866            deployment     hugging_face              False
# 1  0.303870            evaluacion         analisis              False
# 2  0.256311     docs_and_planning    documentacion              False
# 3  0.208302                report         analysis              False
# 4  0.207286                  data  data_processing              False
# 5  0.199838                  goal             plan              False
# 6  0.221744                    ai              llm              False
# 7  0.184115  personal_development       reflection              False
#
#    edge_score   ca   cb
# 0    1.004894  1.0  5.0
# 1    0.868470  4.0  2.0
# 2    0.742771  4.0  1.0
# 3    0.723290  2.0  6.0
# 4    0.652995  2.0  0.0
# 5    0.505705  3.0  5.0
# 6    0.462470  3.0  5.0
# 7    0.383262  5.0  6.0
#
# Column types:
# tag_a                 object
# tag_b                 object
# co_docs                int64
# lift                 float64
# npmi                 float64
# lex_a                 object
# lex_b                 object
# is_tautology_like       bool
# edge_score           float64
# ca                   float64
# cb                   float64
# dtype: object
#
# Non-null counts:
# tag_a                14
# tag_b                14
# co_docs              14
# lift                 14
# npmi                 14
# lex_a                14
# lex_b                14
# is_tautology_like    14
# edge_score           14
# ca                   14
# cb                   14
# dtype: int64
#
# Unique counts:
# tag_a                12
# tag_b                13
# co_docs               5
# lift                 14
# npmi                 14
# lex_a                12
# lex_b                12
# is_tautology_like     1
# edge_score           14
# ca                    5
# cb                    5
# dtype: int64
#
# Top 5 values for tag_a:
# tag_a
# category:docs_and_planning    2
# category:data                 2
# free:deployment               1
# free:evaluacion               1
# format_type:report            1
# msg_type:goal                 1
# category:ai                   1
# free:personal_development     1
# format_type:diagram           1
# free:data_science             1
# free:flask                    1
# free:finance                  1
# Name: count, dtype: int64
#
# Top 5 values for tag_b:
# tag_b
# note_type:analysis           2
# free:hugging_face            1
# note_type:analisis           1
# free:documentacion           1
# domain:data_processing       1
# stage:plan                   1
# free:llm                     1
# msg_type:reflection          1
# stage:reflect                1
# free:software_development    1
# format_type:memo             1
# free:pandas                  1
# free:analisis                1
# Name: count, dtype: int64
#
# Top 5 values for co_docs:
# co_docs
# 2     9
# 3     2
# 10    1
# 7     1
# 4     1
# Name: count, dtype: int64
#
# Top 5 values for lift:
# lift
# 16.417910    1
# 13.483871    1
# 8.088235     1
# 4.254886     1
# 4.549129     1
# 4.817888     1
# 6.675184     1
# 4.488832     1
# 5.367232     1
# 5.225000     1
# 4.917647     1
# 4.878618     1
# 4.837963     1
# 4.799082     1
# Name: count, dtype: int64
#
# Top 5 values for npmi:
# npmi
# 0.326866    1
# 0.303870    1
# 0.256311    1
# 0.208302    1
# 0.207286    1
# 0.199838    1
# 0.221744    1
# 0.184115    1
# 0.196270    1
# 0.193133    1
# 0.186052    1
# 0.185121    1
# 0.184144    1
# 0.183201    1
# Name: count, dtype: int64
#
# Top 5 values for lex_a:
# lex_a
# docs_and_planning       2
# data                    2
# deployment              1
# evaluacion              1
# report                  1
# goal                    1
# ai                      1
# personal_development    1
# diagram                 1
# data_science            1
# flask                   1
# finance                 1
# Name: count, dtype: int64
#
# Top 5 values for lex_b:
# lex_b
# analisis                2
# analysis                2
# hugging_face            1
# documentacion           1
# data_processing         1
# plan                    1
# llm                     1
# reflection              1
# reflect                 1
# software_development    1
# memo                    1
# pandas                  1
# Name: count, dtype: int64
#
# Top 5 values for is_tautology_like:
# is_tautology_like
# False    14
# Name: count, dtype: int64
#
# Top 5 values for edge_score:
# edge_score
# 1.004894    1
# 0.868470    1
# 0.742771    1
# 0.723290    1
# 0.652995    1
# 0.505705    1
# 0.462470    1
# 0.383262    1
# 0.362317    1
# 0.350828    1
# 0.325573    1
# 0.322324    1
# 0.318929    1
# 0.315672    1
# Name: count, dtype: int64
#
# Top 5 values for ca:
# ca
# 2.0    5
# 4.0    3
# 3.0    3
# 1.0    2
# 5.0    1
# Name: count, dtype: int64
#
# Top 5 values for cb:
# cb
# 6.0    6
# 5.0    3
# 0.0    3
# 2.0    1
# 1.0    1
# Name: count, dtype: int64
#
# === edges_default.csv ===
# Shape: (8, 11)
# Columns: ['tag_a', 'tag_b', 'co_docs', 'lift', 'npmi', 'lex_a', 'lex_b', 'is_tautology_like', 'edge_score', 'ca', 'cb']
#                   tag_a                tag_b  co_docs      lift      npmi  \
# 0         msg_type:idea           stage:plan       36  4.360324  0.259670
# 1    format_type:report  msg_type:reflection       44  2.573402  0.172797
# 2   msg_type:reflection        stage:reflect       77  2.130293  0.154007
# 3  category:programming     format_type:code       29  2.378280  0.147166
# 4    format_type:report        stage:reflect       42  2.202838  0.143156
# 5  category:programming        domain:python       38  2.176511  0.138464
# 6         domain:python     format_type:code       34  2.002728  0.121248
# 7  format_type:template           stage:plan       39  1.802856  0.105418
#
#          lex_a       lex_b  is_tautology_like  edge_score   ca   cb
# 0         idea        plan              False    1.380728  5.0  5.0
# 1       report  reflection              False    0.621752  2.0  6.0
# 2   reflection     reflect              False    0.507423  6.0  6.0
# 3  programming        code              False    0.433658  0.0  0.0
# 4       report     reflect              False    0.425229  2.0  6.0
# 5  programming      python              False    0.394518  0.0  0.0
# 6       python        code              False    0.299390  0.0  0.0
# 7     template        plan              False    0.229192  3.0  5.0
#
# Column types:
# tag_a                 object
# tag_b                 object
# co_docs                int64
# lift                 float64
# npmi                 float64
# lex_a                 object
# lex_b                 object
# is_tautology_like       bool
# edge_score           float64
# ca                   float64
# cb                   float64
# dtype: object
#
# Non-null counts:
# tag_a                8
# tag_b                8
# co_docs              8
# lift                 8
# npmi                 8
# lex_a                8
# lex_b                8
# is_tautology_like    8
# edge_score           8
# ca                   8
# cb                   8
# dtype: int64
#
# Unique counts:
# tag_a                6
# tag_b                5
# co_docs              8
# lift                 8
# npmi                 8
# lex_a                6
# lex_b                5
# is_tautology_like    1
# edge_score           8
# ca                   5
# cb                   3
# dtype: int64
#
# Top 5 values for tag_a:
# tag_a
# format_type:report      2
# category:programming    2
# msg_type:idea           1
# msg_type:reflection     1
# domain:python           1
# format_type:template    1
# Name: count, dtype: int64
#
# Top 5 values for tag_b:
# tag_b
# stage:plan             2
# stage:reflect          2
# format_type:code       2
# msg_type:reflection    1
# domain:python          1
# Name: count, dtype: int64
#
# Top 5 values for co_docs:
# co_docs
# 36    1
# 44    1
# 77    1
# 29    1
# 42    1
# 38    1
# 34    1
# 39    1
# Name: count, dtype: int64
#
# Top 5 values for lift:
# lift
# 4.360324    1
# 2.573402    1
# 2.130293    1
# 2.378280    1
# 2.202838    1
# 2.176511    1
# 2.002728    1
# 1.802856    1
# Name: count, dtype: int64
#
# Top 5 values for npmi:
# npmi
# 0.259670    1
# 0.172797    1
# 0.154007    1
# 0.147166    1
# 0.143156    1
# 0.138464    1
# 0.121248    1
# 0.105418    1
# Name: count, dtype: int64
#
# Top 5 values for lex_a:
# lex_a
# report         2
# programming    2
# idea           1
# reflection     1
# python         1
# template       1
# Name: count, dtype: int64
#
# Top 5 values for lex_b:
# lex_b
# plan          2
# reflect       2
# code          2
# reflection    1
# python        1
# Name: count, dtype: int64
#
# Top 5 values for is_tautology_like:
# is_tautology_like
# False    8
# Name: count, dtype: int64
#
# Top 5 values for edge_score:
# edge_score
# 1.380728    1
# 0.621752    1
# 0.507423    1
# 0.433658    1
# 0.425229    1
# 0.394518    1
# 0.299390    1
# 0.229192    1
# Name: count, dtype: int64
#
# Top 5 values for ca:
# ca
# 0.0    3
# 2.0    2
# 5.0    1
# 6.0    1
# 3.0    1
# Name: count, dtype: int64
#
# Top 5 values for cb:
# cb
# 6.0    3
# 0.0    3
# 5.0    2
# Name: count, dtype: int64
#
# === edges_niche.csv ===
# Shape: (8, 11)
# Columns: ['tag_a', 'tag_b', 'co_docs', 'lift', 'npmi', 'lex_a', 'lex_b', 'is_tautology_like', 'edge_score', 'ca', 'cb']
#                      tag_a                  tag_b  co_docs       lift  \
# 0          category:health      domain:healthcare        9  18.441176
# 1  free:career_development  free:job_applications       12   5.851064
# 2  free:career_development   free:job_application        9   5.620966
# 3         msg_type:comment          stage:reflect       18   4.025424
# 4            category:data     free:data_analysis        8   4.708533
# 5       format_type:report     note_type:analysis       10   4.254886
# 6       category:ai_agents          msg_type:idea        9   3.550128
# 7      msg_type:reflection     note_type:analysis       13   2.917741
#
#        npmi               lex_a             lex_b  is_tautology_like  \
# 0  0.412999              health        healthcare              False
# 1  0.260970  career_development  job_applications              False
# 2  0.244647  career_development   job_application              False
# 3  0.218830             comment           reflect              False
# 4  0.215943                data     data_analysis              False
# 5  0.208302              report          analysis              False
# 6  0.179532           ai_agents              idea              False
# 7  0.160075          reflection          analysis              False
#
#    edge_score   ca   cb
# 0    2.771668  7.0  7.0
# 1    1.182533  3.0  3.0
# 2    0.972573  3.0  3.0
# 3    0.897315  6.0  6.0
# 4    0.735142  2.0  2.0
# 5    0.723290  2.0  6.0
# 6    0.523757  5.0  5.0
# 7    0.452361  6.0  6.0
#
# Column types:
# tag_a                 object
# tag_b                 object
# co_docs                int64
# lift                 float64
# npmi                 float64
# lex_a                 object
# lex_b                 object
# is_tautology_like       bool
# edge_score           float64
# ca                   float64
# cb                   float64
# dtype: object
#
# Non-null counts:
# tag_a                8
# tag_b                8
# co_docs              8
# lift                 8
# npmi                 8
# lex_a                8
# lex_b                8
# is_tautology_like    8
# edge_score           8
# ca                   8
# cb                   8
# dtype: int64
#
# Unique counts:
# tag_a                7
# tag_b                7
# co_docs              6
# lift                 8
# npmi                 8
# lex_a                7
# lex_b                7
# is_tautology_like    1
# edge_score           8
# ca                   5
# cb                   5
# dtype: int64
#
# Top 5 values for tag_a:
# tag_a
# free:career_development    2
# category:health            1
# msg_type:comment           1
# category:data              1
# format_type:report         1
# category:ai_agents         1
# msg_type:reflection        1
# Name: count, dtype: int64
#
# Top 5 values for tag_b:
# tag_b
# note_type:analysis       2
# domain:healthcare        1
# free:job_applications    1
# free:job_application     1
# stage:reflect            1
# free:data_analysis       1
# msg_type:idea            1
# Name: count, dtype: int64
#
# Top 5 values for co_docs:
# co_docs
# 9     3
# 12    1
# 18    1
# 8     1
# 10    1
# 13    1
# Name: count, dtype: int64
#
# Top 5 values for lift:
# lift
# 18.441176    1
# 5.851064     1
# 5.620966     1
# 4.025424     1
# 4.708533     1
# 4.254886     1
# 3.550128     1
# 2.917741     1
# Name: count, dtype: int64
#
# Top 5 values for npmi:
# npmi
# 0.412999    1
# 0.260970    1
# 0.244647    1
# 0.218830    1
# 0.215943    1
# 0.208302    1
# 0.179532    1
# 0.160075    1
# Name: count, dtype: int64
#
# Top 5 values for lex_a:
# lex_a
# career_development    2
# health                1
# comment               1
# data                  1
# report                1
# ai_agents             1
# reflection            1
# Name: count, dtype: int64
#
# Top 5 values for lex_b:
# lex_b
# analysis            2
# healthcare          1
# job_applications    1
# job_application     1
# reflect             1
# data_analysis       1
# idea                1
# Name: count, dtype: int64
#
# Top 5 values for is_tautology_like:
# is_tautology_like
# False    8
# Name: count, dtype: int64
#
# Top 5 values for edge_score:
# edge_score
# 2.771668    1
# 1.182533    1
# 0.972573    1
# 0.897315    1
# 0.735142    1
# 0.723290    1
# 0.523757    1
# 0.452361    1
# Name: count, dtype: int64
#
# Top 5 values for ca:
# ca
# 3.0    2
# 6.0    2
# 2.0    2
# 7.0    1
# 5.0    1
# Name: count, dtype: int64
#
# Top 5 values for cb:
# cb
# 6.0    3
# 3.0    2
# 7.0    1
# 2.0    1
# 5.0    1
# Name: count, dtype: int64
#
# === edges_audit.csv ===
# Shape: (237, 11)
# Columns: ['tag_a', 'tag_b', 'co_docs', 'lift', 'npmi', 'lex_a', 'lex_b', 'is_tautology_like', 'edge_score', 'ca', 'cb']
#                              tag_a                    tag_b  co_docs  \
# 0                     free:recetas         note_type:receta        2
# 1                 category:cooking          domain:culinary        2
# 2                      free:cocina         note_type:receta        2
# 3       domain:audio_transcription  note_type:transcription        2
# 4                      free:cocina             free:recetas        2
# 5                  category:health       free:mental_health        2
# 6  format_type:audio_transcription  note_type:transcription        2
# 7  format_type:audio_transcription       free:communication        2
#
#          lift      npmi                lex_a          lex_b  \
# 0  146.153846  0.582238              recetas         receta
# 1  139.333333  0.576655              cooking       culinary
# 2  126.666667  0.565523               cocina         receta
# 3  118.750000  0.557984  audio_transcription  transcription
# 4  107.179487  0.546010               cocina        recetas
# 5  102.450980  0.540739               health  mental_health
# 6   76.838235  0.507136  audio_transcription  transcription
# 7   76.838235  0.507136  audio_transcription  communication
#
#    is_tautology_like  edge_score   ca   cb
# 0              False    3.188455  8.0  8.0
# 1              False    3.127609  8.0  8.0
# 2              False    3.008013  8.0  8.0
# 3              False    2.928353  6.0  6.0
# 4              False    2.804016  8.0  8.0
# 5              False    2.750146  7.0  7.0
# 6              False    2.418964  6.0  6.0
# 7              False    2.418964  6.0  6.0
#
# Column types:
# tag_a                 object
# tag_b                 object
# co_docs                int64
# lift                 float64
# npmi                 float64
# lex_a                 object
# lex_b                 object
# is_tautology_like       bool
# edge_score           float64
# ca                   float64
# cb                   float64
# dtype: object
#
# Non-null counts:
# tag_a                237
# tag_b                237
# co_docs              237
# lift                 237
# npmi                 237
# lex_a                237
# lex_b                237
# is_tautology_like    237
# edge_score           237
# ca                   237
# cb                   237
# dtype: int64
#
# Unique counts:
# tag_a                102
# tag_b                125
# co_docs                6
# lift                 212
# npmi                 217
# lex_a                 92
# lex_b                114
# is_tautology_like      1
# edge_score           217
# ca                    10
# cb                    10
# dtype: int64
#
# Top 5 values for tag_a:
# tag_a
# category:docs_and_planning    14
# category:business             14
# category:data                 14
# free:career_development        8
# category:software_dev          7
# domain:docusaurus              6
# category:other                 6
# category:automation            6
# category:health                5
# free:analisis_de_datos         5
# free:deployment                4
# domain:data_analysis           4
# free:job_application           4
# category:ai_agents             4
# category:cooking               4
# Name: count, dtype: int64
#
# Top 5 values for tag_b:
# tag_b
# free:web_development         13
# stage:plan                    8
# msg_type:question             6
# free:software_development     6
# free:job_applications         5
# stage:reflect                 5
# free:pandas                   4
# stage:package                 4
# note_type:analisis            4
# note_type:evaluacion          4
# note_type:insight             4
# note_type:solution            4
# msg_type:reflection           4
# free:career_development       4
# free:python                   4
# Name: count, dtype: int64
#
# Top 5 values for co_docs:
# co_docs
# 2    139
# 3     56
# 4     16
# 5     12
# 6     10
# 7      4
# Name: count, dtype: int64
#
# Top 5 values for lift:
# lift
# 17.075163    4
# 4.799082     4
# 3.042213     3
# 11.908832    3
# 4.488832     3
# 5.293820     2
# 33.493590    2
# 3.367709     2
# 14.131170    2
# 5.780933     2
# 3.119403     2
# 5.367232     2
# 6.304676     2
# 5.225000     2
# 3.263076     2
# Name: count, dtype: int64
#
# Top 5 values for npmi:
# npmi
# 0.183201    4
# 0.331451    4
# 0.136417    3
# 0.410147    2
# 0.184115    2
# 0.194662    2
# 0.215132    2
# 0.309347    2
# 0.215074    2
# 0.138143    2
# 0.193133    2
# 0.507136    2
# 0.181310    2
# 0.148881    2
# 0.132049    2
# Name: count, dtype: int64
#
# Top 5 values for lex_a:
# lex_a
# data                   18
# business               14
# docs_and_planning      14
# automation              8
# career_development      8
# docusaurus              7
# software_dev            7
# other                   6
# analisis_de_datos       5
# data_analysis           5
# data_processing         5
# health                  5
# data_science            4
# audio_transcription     4
# cooking                 4
# Name: count, dtype: int64
#
# Top 5 values for lex_b:
# lex_b
# web_development         14
# plan                     8
# job_applications         8
# evaluacion               7
# question                 6
# software_development     6
# reflect                  5
# analisis                 5
# pandas                   4
# documentation            4
# insight                  4
# data_science             4
# solution                 4
# reflection               4
# career_development       4
# Name: count, dtype: int64
#
# Top 5 values for is_tautology_like:
# is_tautology_like
# False    237
# Name: count, dtype: int64
#
# Top 5 values for edge_score:
# edge_score
# 0.315672    4
# 1.033283    4
# 0.210406    3
# 1.582190    2
# 0.383262    2
# 0.356403    2
# 0.523276    2
# 0.900059    2
# 0.435065    2
# 0.179488    2
# 0.350828    2
# 2.418964    2
# 0.450296    2
# 0.250608    2
# 0.164003    2
# Name: count, dtype: int64
#
# Top 5 values for ca:
# ca
# 3.0    45
# 2.0    43
# 0.0    37
# 1.0    37
# 4.0    20
# 5.0    19
# 6.0    18
# 7.0    10
# 8.0     7
# 9.0     1
# Name: count, dtype: int64
#
# Top 5 values for cb:
# cb
# 0.0    44
# 2.0    41
# 3.0    40
# 1.0    35
# 6.0    24
# 5.0    22
# 4.0    14
# 7.0     9
# 8.0     7
# 9.0     1
# Name: count, dtype: int64
#
# === tag_communities.csv ===
# Shape: (206, 2)
# Columns: ['tag', 'community']
#                       tag  community
# 0  note_type:code_snippet          0
# 1              free:jsonl          0
# 2             free:pandas          0
# 3             free:sqlite          0
# 4             free:chroma          0
# 5          free:dataframe          0
# 6     free:error_handling          0
# 7           domain:python          0
#
# Column types:
# tag          object
# community     int64
# dtype: object
#
# Non-null counts:
# tag          206
# community    206
# dtype: int64
#
# Unique counts:
# tag          206
# community     10
# dtype: int64
#
# Top 5 values for tag:
# tag
# note_type:code_snippet        1
# free:evaluacion               1
# free:job_listings             1
# category:docs_and_planning    1
# free:productivity             1
# free:database_management      1
# domain:next.js                1
# free:content_creation         1
# domain:writing                1
# free:educacion                1
# free:logging                  1
# domain:documentation          1
# free:etl                      1
# domain:latex                  1
# free:yaml                     1
# Name: count, dtype: int64
#
# Top 5 values for community:
# community
# 0    40
# 1    32
# 2    28
# 3    26
# 4    26
# 5    21
# 6    19
# 7     7
# 8     5
# 9     2
# Name: count, dtype: int64
#
# === gates.json ===
# CO_DEFAULT: 20
# CO_BACKBONE: 35
# CO_NICHE_LO: 8
# CO_NICHE_HI: 35
# NPMI_KEEP: 0.1
# LIFT_KEEP: 2.1
# NPMI_STRONG: 0.12
# LIFT_STRONG: 2.3
# NPMI_VSTRONG: 0.16
# LIFT_VSTRONG: 3.0
# NPMI_BRIDGE: 0.18
#
# === quantiles.json ===
# co: {'0.5': 3.0, '0.75': 4.0, '0.9': 9.0}
# lift: {'0.5': 2.364253393665159, '0.75': 4.488831615120275, '0.9': 10.467032967032974}
# npmi: {'0.5': 0.10595725869391999, '0.75': 0.18320126588591956, '0.9': 0.2796749694161444}
#
# === counts.json ===
# default: 8
# backbone: 1
# niche: 8
# bridges: 14
# audit: 237
#
# === index.json ===
# pairs_rows: 619
# communities_rows: 206
# params: {'top_k': 800, 'min_docs': 2, 'min_npmi': 0.02}
# gates_source: json

# %%
# !tree ./../outputs/eda_units/may-aug_daily_combo2_soft/

# %%
csv_files
# Out:
# ['co_tag_pairs.csv',
#  'doc_tag_long.csv',
#  'edges_backbone.csv',
#  'edges_bridges.csv',
#  'edges_default.csv',
#  'edges_niche.csv',
#  'edges_audit.csv',
#  'tag_communities.csv']
